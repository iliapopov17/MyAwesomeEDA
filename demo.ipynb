# %%
import pandas as pd
from my_awesome_eda import run_eda

# %%
df = pd.read_csv('demo_data/titanic.csv')

# %%
run_eda(df)
# Out:
# Welcome to the Awesome EDA Module!
#     <img src="imgs/welcome.gif" width="200" height="200">
# Number of observations (rows):
# 891
# Number of parameters (columns):
# 12
#
# ===== ===== ===== ===== ===== =====
# ===== ===== ===== ===== ===== =====
# Column Data Types:
# - int64: PassengerId, Survived, Pclass, SibSp, Parch
# - object: Name, Sex, Ticket, Cabin, Embarked
# - float64: Age, Fare
#
# ===== ===== ===== ===== ===== =====
# ===== ===== ===== ===== ===== =====
# Feature Categories:
# - Numerical: ['PassengerId', 'Age', 'SibSp', 'Parch', 'Fare']
# - Strings: ['Name', 'Ticket', 'Cabin']
# - Categoricals: ['Survived', 'Pclass', 'Sex', 'Embarked']
#
# ===== ===== ===== ===== ===== =====
# ===== ===== ===== ===== ===== =====
# Value Counts and Frequencies:
# - Survived: 0 = 549 (61.62%), 1 = 342 (38.38%)
# - Pclass: 3 = 491 (55.11%), 1 = 216 (24.24%), 2 = 184 (20.65%)
# - Sex: male = 577 (64.76%), female = 314 (35.24%)
# ...
